# %%
pip install -r ./requirements.txt
# Out:
# Requirement already satisfied: gradio in c:\users\merve\anaconda3\lib\site-packages (from -r ./requirements.txt (line 1)) (4.31.4)
# Requirement already satisfied: stylecloud in c:\users\merve\anaconda3\lib\site-packages (from -r ./requirements.txt (line 2)) (0.5.2)
# Collecting Image (from -r ./requirements.txt (line 3))Note: you may need to restart the kernel to use updated packages.
#   Downloading image-1.5.33.tar.gz (15 kB)
#
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: aiofiles<24.0,>=22.0 in c:\users\merve\anaconda3\lib\site-packages (from gradio->-r ./requirements.txt (line 1)) (22.1.0)
# Requirement already satisfied: altair<6.0,>=4.2.0 in c:\users\merve\anaconda3\lib\site-packages (from gradio->-r ./requirements.txt (line 1)) (5.0.1)
# Requirement already satisfied: fastapi in c:\users\merve\anaconda3\lib\site-packages (from gradio->-r ./requirements.txt (line 1)) (0.111.0)
# Requirement already satisfied: ffmpy in c:\users\merve\anaconda3\lib\site-packages (from gradio->-r ./requirements.txt (line 1)) (0.3.2)
# Requirement already satisfied: gradio-client==0.16.4 in c:\users\merve\anaconda3\lib\site-packages (from gradio->-r ./requirements.txt (line 1)) (0.16.4)
# Requirement already satisfied: httpx>=0.24.1 in c:\users\merve\anaconda3\lib\site-packages (from gradio->-r ./requirements.txt (line 1)) (0.27.0)
# Requirement already satisfied: huggingface-hub>=0.19.3 in c:\users\merve\anaconda3\lib\site-packages (from gradio->-r ./requirements.txt (line 1)) (0.23.0)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in c:\users\merve\anaconda3\lib\site-packages (from gradio->-r ./requirements.txt (line 1)) (6.4.0)
# Requirement already satisfied: jinja2<4.0 in c:\users\merve\anaconda3\lib\site-packages (from gradio->-r ./requirements.txt (line 1)) (3.1.3)
# Requirement already satisfied: markupsafe~=2.0 in c:\users\merve\anaconda3\lib\site-packages (from gradio->-r ./requirements.txt (line 1)) (2.1.3)
# Requirement already satisfied: matplotlib~=3.0 in c:\users\merve\anaconda3\lib\site-packages (from gradio->-r ./requirements.txt (line 1)) (3.8.0)
# Requirement already satisfied: numpy~=1.0 in c:\users\merve\anaconda3\lib\site-packages (from gradio->-r ./requirements.txt (line 1)) (1.26.4)

# %%
# Gerekli kütüphaneleri içe aktar
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import string
import stylecloud
from PIL import Image
import matplotlib.pyplot as plt

# NLTK kütüphanesinden gerekli bileşenleri indir
nltk.download('stopwords')
nltk.download('punkt')

def preprocess_and_create_stylecloud(file_path, output_name='stylecloud.png', 
                                     icon_name='fas fa-coffee', lang='turkish'):
    # Metni dosyadan oku
    with open(file_path, 'r', encoding='utf-8') as f:
        text = f.read()

    # Türkçe stopwords listesini yükle
    stop_words = set(stopwords.words(lang))

    # Noktalama işaretlerini kaldır
    translator = str.maketrans('', '', string.punctuation)
    text = text.translate(translator)

    # Metni tokenlere ayır ve küçük harfe çevir
    tokens = word_tokenize(text.lower(), language=lang)

    # Stopwords'ü filtrele
    filtered_tokens = [word for word in tokens if word not in stop_words]

    # Filtrelenmiş tokenleri birleştir
    processed_text = ' '.join(filtered_tokens)

    # StyleCloud oluştur
    stylecloud.gen_stylecloud(text=processed_text,
                              icon_name=icon_name,
                              output_name=output_name)
    # Oluşturulan StyleCloud'u göster
    im = Image.open(output_name)
    plt.figure(figsize=(10, 10))
    plt.imshow(im)
    plt.axis('off')  # Eksenleri gizle
    plt.show()
# Out:
# Requirement already satisfied: orjson~=3.0 in c:\users\merve\anaconda3\lib\site-packages (from gradio->-r ./requirements.txt (line 1)) (3.10.3)
# Requirement already satisfied: packaging in c:\users\merve\anaconda3\lib\site-packages (from gradio->-r ./requirements.txt (line 1)) (23.1)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\merve\anaconda3\lib\site-packages (from gradio->-r ./requirements.txt (line 1)) (2.1.4)
# Requirement already satisfied: pillow<11.0,>=8.0 in c:\users\merve\anaconda3\lib\site-packages (from gradio->-r ./requirements.txt (line 1)) (10.2.0)
# Requirement already satisfied: pydantic>=2.0 in c:\users\merve\anaconda3\lib\site-packages (from gradio->-r ./requirements.txt (line 1)) (2.7.1)
# Requirement already satisfied: pydub in c:\users\merve\anaconda3\lib\site-packages (from gradio->-r ./requirements.txt (line 1)) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\merve\anaconda3\lib\site-packages (from gradio->-r ./requirements.txt (line 1)) (0.0.9)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\merve\anaconda3\lib\site-packages (from gradio->-r ./requirements.txt (line 1)) (6.0.1)
# Requirement already satisfied: ruff>=0.2.2 in c:\users\merve\anaconda3\lib\site-packages (from gradio->-r ./requirements.txt (line 1)) (0.4.4)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\merve\anaconda3\lib\site-packages (from gradio->-r ./requirements.txt (line 1)) (2.10.0)
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\merve\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\merve\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Requirement already satisfied: tomlkit==0.12.0 in c:\users\merve\anaconda3\lib\site-packages (from gradio->-r ./requirements.txt (line 1)) (0.12.0)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\merve\anaconda3\lib\site-packages (from gradio->-r ./requirements.txt (line 1)) (0.12.3)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\merve\anaconda3\lib\site-packages (from gradio->-r ./requirements.txt (line 1)) (4.9.0)
# Requirement already satisfied: urllib3~=2.0 in c:\users\merve\anaconda3\lib\site-packages (from gradio->-r ./requirements.txt (line 1)) (2.0.7)

# %%
preprocess_and_create_stylecloud(file_path='genclige_hitabe.txt', 
                                 output_name='ay_yildiz.png', icon_name='fas fa-star-and-crescent', lang='turkish')
# Out:
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\merve\anaconda3\lib\site-packages (from gradio->-r ./requirements.txt (line 1)) (0.29.0)
# Requirement already satisfied: fsspec in c:\users\merve\anaconda3\lib\site-packages (from gradio-client==0.16.4->gradio->-r ./requirements.txt (line 1)) (2023.10.0)
# Requirement already satisfied: websockets<12.0,>=10.0 in c:\users\merve\anaconda3\lib\site-packages (from gradio-client==0.16.4->gradio->-r ./requirements.txt (line 1)) (11.0.3)
# Requirement already satisfied: wordcloud in c:\users\merve\anaconda3\lib\site-packages (from stylecloud->-r ./requirements.txt (line 2)) (1.9.3)
# Requirement already satisfied: icon-font-to-png in c:\users\merve\anaconda3\lib\site-packages (from stylecloud->-r ./requirements.txt (line 2)) (0.4.1)
# Requirement already satisfied: palettable in c:\users\merve\anaconda3\lib\site-packages (from stylecloud->-r ./requirements.txt (line 2)) (3.3.3)
# Requirement already satisfied: fire in c:\users\merve\anaconda3\lib\site-packages (from stylecloud->-r ./requirements.txt (line 2)) (0.6.0)
# Collecting django (from Image->-r ./requirements.txt (line 3))
#   Downloading Django-5.0.6-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: six in c:\users\merve\anaconda3\lib\site-packages (from Image->-r ./requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\merve\anaconda3\lib\site-packages (from altair<6.0,>=4.2.0->gradio->-r ./requirements.txt (line 1)) (4.19.2)
# Requirement already satisfied: toolz in c:\users\merve\anaconda3\lib\site-packages (from altair<6.0,>=4.2.0->gradio->-r ./requirements.txt (line 1)) (0.12.0)
# Requirement already satisfied: anyio in c:\users\merve\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio->-r ./requirements.txt (line 1)) (4.2.0)
# Requirement already satisfied: certifi in c:\users\merve\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio->-r ./requirements.txt (line 1)) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in c:\users\merve\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio->-r ./requirements.txt (line 1)) (1.0.5)
# Requirement already satisfied: idna in c:\users\merve\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio->-r ./requirements.txt (line 1)) (2.10)
# Requirement already satisfied: sniffio in c:\users\merve\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio->-r ./requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\merve\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.24.1->gradio->-r ./requirements.txt (line 1)) (0.14.0)
# Requirement already satisfied: filelock in c:\users\merve\anaconda3\lib\site-packages (from huggingface-hub>=0.19.3->gradio->-r ./requirements.txt (line 1)) (3.13.1)
# Requirement already satisfied: requests in c:\users\merve\anaconda3\lib\site-packages (from huggingface-hub>=0.19.3->gradio->-r ./requirements.txt (line 1)) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\merve\anaconda3\lib\site-packages (from huggingface-hub>=0.19.3->gradio->-r ./requirements.txt (line 1)) (4.65.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\merve\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio->-r ./requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\merve\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio->-r ./requirements.txt (line 1)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\merve\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio->-r ./requirements.txt (line 1)) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\merve\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio->-r ./requirements.txt (line 1)) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\merve\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio->-r ./requirements.txt (line 1)) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\merve\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio->-r ./requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\merve\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio->-r ./requirements.txt (line 1)) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\merve\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio->-r ./requirements.txt (line 1)) (2023.3)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\merve\anaconda3\lib\site-packages (from pydantic>=2.0->gradio->-r ./requirements.txt (line 1)) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in c:\users\merve\anaconda3\lib\site-packages (from pydantic>=2.0->gradio->-r ./requirements.txt (line 1)) (2.18.2)
# Requirement already satisfied: click>=8.0.0 in c:\users\merve\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio->-r ./requirements.txt (line 1)) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\merve\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio->-r ./requirements.txt (line 1)) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\merve\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio->-r ./requirements.txt (line 1)) (13.3.5)
# Collecting asgiref<4,>=3.7.0 (from django->Image->-r ./requirements.txt (line 3))
#   Downloading asgiref-3.8.1-py3-none-any.whl.metadata (9.3 kB)
# Collecting sqlparse>=0.3.1 (from django->Image->-r ./requirements.txt (line 3))
#   Downloading sqlparse-0.5.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in c:\users\merve\anaconda3\lib\site-packages (from fastapi->gradio->-r ./requirements.txt (line 1)) (0.37.2)
# Requirement already satisfied: fastapi-cli>=0.0.2 in c:\users\merve\anaconda3\lib\site-packages (from fastapi->gradio->-r ./requirements.txt (line 1)) (0.0.4)
# Requirement already satisfied: ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 in c:\users\merve\anaconda3\lib\site-packages (from fastapi->gradio->-r ./requirements.txt (line 1)) (5.4.0)
# Requirement already satisfied: email_validator>=2.0.0 in c:\users\merve\anaconda3\lib\site-packages (from fastapi->gradio->-r ./requirements.txt (line 1)) (2.1.1)
# Requirement already satisfied: termcolor in c:\users\merve\anaconda3\lib\site-packages (from fire->stylecloud->-r ./requirements.txt (line 2)) (2.4.0)
# Requirement already satisfied: tinycss>=0.4 in c:\users\merve\anaconda3\lib\site-packages (from icon-font-to-png->stylecloud->-r ./requirements.txt (line 2)) (0.4)
# Requirement already satisfied: colorama in c:\users\merve\anaconda3\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio->-r ./requirements.txt (line 1)) (0.4.6)
# Requirement already satisfied: dnspython>=2.0.0 in c:\users\merve\anaconda3\lib\site-packages (from email_validator>=2.0.0->fastapi->gradio->-r ./requirements.txt (line 1)) (2.6.1)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\merve\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio->-r ./requirements.txt (line 1)) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\merve\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio->-r ./requirements.txt (line 1)) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\merve\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio->-r ./requirements.txt (line 1)) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\merve\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio->-r ./requirements.txt (line 1)) (0.10.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\merve\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.19.3->gradio->-r ./requirements.txt (line 1)) (2.0.4)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\merve\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio->-r ./requirements.txt (line 1)) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\merve\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio->-r ./requirements.txt (line 1)) (2.15.1)
# Requirement already satisfied: httptools>=0.5.0 in c:\users\merve\anaconda3\lib\site-packages (from uvicorn[standard]>=0.12.0->fastapi->gradio->-r ./requirements.txt (line 1)) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\merve\anaconda3\lib\site-packages (from uvicorn[standard]>=0.12.0->fastapi->gradio->-r ./requirements.txt (line 1)) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\merve\anaconda3\lib\site-packages (from uvicorn[standard]>=0.12.0->fastapi->gradio->-r ./requirements.txt (line 1)) (0.21.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\merve\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio->-r ./requirements.txt (line 1)) (0.1.0)
# Downloading Django-5.0.6-py3-none-any.whl (8.2 MB)
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.2 MB 660.6 kB/s eta 0:00:13
#    ---------------------------------------- 0.0/8.2 MB 393.8 kB/s eta 0:00:21
#    ---------------------------------------- 0.0/8.2 MB 393.8 kB/s eta 0:00:21
#    ---------------------------------------- 0.0/8.2 MB 393.8 kB/s eta 0:00:21
#     --------------------------------------- 0.1/8.2 MB 595.3 kB/s eta 0:00:14
#     --------------------------------------- 0.2/8.2 MB 748.1 kB/s eta 0:00:11
#    - -------------------------------------- 0.2/8.2 MB 811.5 kB/s eta 0:00:10
#    - -------------------------------------- 0.3/8.2 MB 787.7 kB/s eta 0:00:11
#    - -------------------------------------- 0.3/8.2 MB 842.9 kB/s eta 0:00:10
#    - -------------------------------------- 0.3/8.2 MB 787.7 kB/s eta 0:00:10
#    - -------------------------------------- 0.4/8.2 MB 849.3 kB/s eta 0:00:10
#    - -------------------------------------- 0.4/8.2 MB 859.0 kB/s eta 0:00:10
#    -- ------------------------------------- 0.5/8.2 MB 880.6 kB/s eta 0:00:09
#    -- ------------------------------------- 0.5/8.2 MB 894.8 kB/s eta 0:00:09
#    -- ------------------------------------- 0.5/8.2 MB 911.0 kB/s eta 0:00:09
#    -- ------------------------------------- 0.6/8.2 MB 891.2 kB/s eta 0:00:09
#    -- ------------------------------------- 0.6/8.2 MB 905.4 kB/s eta 0:00:09
#    --- ------------------------------------ 0.6/8.2 MB 909.2 kB/s eta 0:00:09
#    --- ------------------------------------ 0.6/8.2 MB 903.1 kB/s eta 0:00:09
#    --- ------------------------------------ 0.7/8.2 MB 942.1 kB/s eta 0:00:08
#    --- ------------------------------------ 0.7/8.2 MB 925.1 kB/s eta 0:00:09
#    --- ------------------------------------ 0.8/8.2 MB 952.3 kB/s eta 0:00:08
#    ---- ----------------------------------- 0.8/8.2 MB 953.7 kB/s eta 0:00:08
#    ---- ----------------------------------- 0.9/8.2 MB 960.7 kB/s eta 0:00:08
#    ---- ----------------------------------- 0.9/8.2 MB 967.1 kB/s eta 0:00:08
#    ---- ----------------------------------- 1.0/8.2 MB 982.8 kB/s eta 0:00:08
#    ----- ---------------------------------- 1.0/8.2 MB 993.2 kB/s eta 0:00:08
#    ----- ---------------------------------- 1.1/8.2 MB 1.0 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.1/8.2 MB 1.0 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.2/8.2 MB 1.0 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.2/8.2 MB 1.0 MB/s eta 0:00:07
#    ------ --------------------------------- 1.3/8.2 MB 1.0 MB/s eta 0:00:07
#    ------ --------------------------------- 1.3/8.2 MB 1.1 MB/s eta 0:00:07
#    ------ --------------------------------- 1.4/8.2 MB 1.1 MB/s eta 0:00:07
#    ------ --------------------------------- 1.4/8.2 MB 1.1 MB/s eta 0:00:07
#    ------- -------------------------------- 1.5/8.2 MB 1.1 MB/s eta 0:00:07
#    ------- -------------------------------- 1.5/8.2 MB 1.1 MB/s eta 0:00:07
#    ------- -------------------------------- 1.6/8.2 MB 1.1 MB/s eta 0:00:07
#    ------- -------------------------------- 1.6/8.2 MB 1.1 MB/s eta 0:00:06
#    -------- ------------------------------- 1.7/8.2 MB 1.1 MB/s eta 0:00:06
#    -------- ------------------------------- 1.7/8.2 MB 1.1 MB/s eta 0:00:06
#    -------- ------------------------------- 1.8/8.2 MB 1.1 MB/s eta 0:00:06
#    -------- ------------------------------- 1.8/8.2 MB 1.1 MB/s eta 0:00:06
#    --------- ------------------------------ 1.9/8.2 MB 1.1 MB/s eta 0:00:06
#    --------- ------------------------------ 1.9/8.2 MB 1.1 MB/s eta 0:00:06
#    --------- ------------------------------ 2.0/8.2 MB 1.1 MB/s eta 0:00:06
#    --------- ------------------------------ 2.0/8.2 MB 1.1 MB/s eta 0:00:06
#    ---------- ----------------------------- 2.1/8.2 MB 1.2 MB/s eta 0:00:06
#    ---------- ----------------------------- 2.1/8.2 MB 1.2 MB/s eta 0:00:06
#    ---------- ----------------------------- 2.2/8.2 MB 1.2 MB/s eta 0:00:06
#    ----------- ---------------------------- 2.3/8.2 MB 1.2 MB/s eta 0:00:06
#    ----------- ---------------------------- 2.3/8.2 MB 1.2 MB/s eta 0:00:06
#    ----------- ---------------------------- 2.4/8.2 MB 1.2 MB/s eta 0:00:05
#    ----------- ---------------------------- 2.4/8.2 MB 1.2 MB/s eta 0:00:05
#    ------------ --------------------------- 2.5/8.2 MB 1.2 MB/s eta 0:00:05
#    ------------ --------------------------- 2.5/8.2 MB 1.2 MB/s eta 0:00:05
#    ------------ --------------------------- 2.6/8.2 MB 1.2 MB/s eta 0:00:05
#    ------------ --------------------------- 2.6/8.2 MB 1.2 MB/s eta 0:00:05
#    ------------- -------------------------- 2.7/8.2 MB 1.2 MB/s eta 0:00:05
#    ------------- -------------------------- 2.7/8.2 MB 1.2 MB/s eta 0:00:05
#    ------------- -------------------------- 2.8/8.2 MB 1.2 MB/s eta 0:00:05
#    ------------- -------------------------- 2.8/8.2 MB 1.2 MB/s eta 0:00:05
#    -------------- ------------------------- 2.9/8.2 MB 1.2 MB/s eta 0:00:05
#    -------------- ------------------------- 3.0/8.2 MB 1.2 MB/s eta 0:00:05
#    -------------- ------------------------- 3.0/8.2 MB 1.2 MB/s eta 0:00:05
#    --------------- ------------------------ 3.1/8.2 MB 1.2 MB/s eta 0:00:05
#    --------------- ------------------------ 3.1/8.2 MB 1.2 MB/s eta 0:00:05
#    --------------- ------------------------ 3.2/8.2 MB 1.3 MB/s eta 0:00:05
#    --------------- ------------------------ 3.2/8.2 MB 1.3 MB/s eta 0:00:04
#    ---------------- ----------------------- 3.3/8.2 MB 1.3 MB/s eta 0:00:04
#    ---------------- ----------------------- 3.4/8.2 MB 1.3 MB/s eta 0:00:04
#    ---------------- ----------------------- 3.4/8.2 MB 1.3 MB/s eta 0:00:04
#    ---------------- ----------------------- 3.5/8.2 MB 1.3 MB/s eta 0:00:04
#    ----------------- ---------------------- 3.5/8.2 MB 1.3 MB/s eta 0:00:04
#    ----------------- ---------------------- 3.6/8.2 MB 1.3 MB/s eta 0:00:04
#    ----------------- ---------------------- 3.6/8.2 MB 1.3 MB/s eta 0:00:04
#    ------------------ --------------------- 3.7/8.2 MB 1.3 MB/s eta 0:00:04
#    ------------------ --------------------- 3.7/8.2 MB 1.3 MB/s eta 0:00:04
#    ------------------ --------------------- 3.8/8.2 MB 1.3 MB/s eta 0:00:04
#    ------------------ --------------------- 3.9/8.2 MB 1.3 MB/s eta 0:00:04
#    ------------------- -------------------- 3.9/8.2 MB 1.3 MB/s eta 0:00:04
#    ------------------- -------------------- 4.0/8.2 MB 1.3 MB/s eta 0:00:04
#    ------------------- -------------------- 4.0/8.2 MB 1.3 MB/s eta 0:00:04
#    ------------------- -------------------- 4.1/8.2 MB 1.3 MB/s eta 0:00:04
#    -------------------- ------------------- 4.1/8.2 MB 1.3 MB/s eta 0:00:04
#    -------------------- ------------------- 4.2/8.2 MB 1.3 MB/s eta 0:00:04
#    -------------------- ------------------- 4.3/8.2 MB 1.3 MB/s eta 0:00:03
#    --------------------- ------------------ 4.3/8.2 MB 1.3 MB/s eta 0:00:03
#    --------------------- ------------------ 4.4/8.2 MB 1.3 MB/s eta 0:00:03
#    --------------------- ------------------ 4.4/8.2 MB 1.3 MB/s eta 0:00:03
#    --------------------- ------------------ 4.5/8.2 MB 1.3 MB/s eta 0:00:03
#    ---------------------- ----------------- 4.5/8.2 MB 1.3 MB/s eta 0:00:03
#    ---------------------- ----------------- 4.6/8.2 MB 1.3 MB/s eta 0:00:03
#    ---------------------- ----------------- 4.6/8.2 MB 1.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 4.7/8.2 MB 1.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 4.8/8.2 MB 1.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 4.8/8.2 MB 1.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 4.9/8.2 MB 1.3 MB/s eta 0:00:03
#    ------------------------ --------------- 5.0/8.2 MB 1.3 MB/s eta 0:00:03
#    ------------------------ --------------- 5.0/8.2 MB 1.3 MB/s eta 0:00:03
#    ------------------------ --------------- 5.1/8.2 MB 1.3 MB/s eta 0:00:03
#    ------------------------- -------------- 5.1/8.2 MB 1.3 MB/s eta 0:00:03
#    ------------------------- -------------- 5.2/8.2 MB 1.3 MB/s eta 0:00:03
#    ------------------------- -------------- 5.2/8.2 MB 1.3 MB/s eta 0:00:03
#    ------------------------- -------------- 5.3/8.2 MB 1.3 MB/s eta 0:00:03
#    -------------------------- ------------- 5.3/8.2 MB 1.3 MB/s eta 0:00:03
#    -------------------------- ------------- 5.4/8.2 MB 1.3 MB/s eta 0:00:03
#    -------------------------- ------------- 5.4/8.2 MB 1.3 MB/s eta 0:00:03
#    -------------------------- ------------- 5.5/8.2 MB 1.3 MB/s eta 0:00:03
#    --------------------------- ------------ 5.6/8.2 MB 1.3 MB/s eta 0:00:02
#    --------------------------- ------------ 5.6/8.2 MB 1.3 MB/s eta 0:00:02
#    --------------------------- ------------ 5.7/8.2 MB 1.4 MB/s eta 0:00:02
#    --------------------------- ------------ 5.7/8.2 MB 1.4 MB/s eta 0:00:02
#    ---------------------------- ----------- 5.8/8.2 MB 1.4 MB/s eta 0:00:02
#    ---------------------------- ----------- 5.9/8.2 MB 1.4 MB/s eta 0:00:02
#    ---------------------------- ----------- 5.9/8.2 MB 1.4 MB/s eta 0:00:02
#    ----------------------------- ---------- 6.0/8.2 MB 1.4 MB/s eta 0:00:02
#    ----------------------------- ---------- 6.1/8.2 MB 1.4 MB/s eta 0:00:02
#    ----------------------------- ---------- 6.1/8.2 MB 1.4 MB/s eta 0:00:02
#    ------------------------------ --------- 6.2/8.2 MB 1.4 MB/s eta 0:00:02
#    ------------------------------ --------- 6.3/8.2 MB 1.4 MB/s eta 0:00:02
#    ------------------------------ --------- 6.3/8.2 MB 1.4 MB/s eta 0:00:02
#    ------------------------------- -------- 6.4/8.2 MB 1.4 MB/s eta 0:00:02
#    ------------------------------- -------- 6.5/8.2 MB 1.4 MB/s eta 0:00:02
#    ------------------------------- -------- 6.5/8.2 MB 1.4 MB/s eta 0:00:02
#    -------------------------------- ------- 6.6/8.2 MB 1.4 MB/s eta 0:00:02
#    -------------------------------- ------- 6.7/8.2 MB 1.4 MB/s eta 0:00:02
#    -------------------------------- ------- 6.7/8.2 MB 1.4 MB/s eta 0:00:02
#    --------------------------------- ------ 6.8/8.2 MB 1.4 MB/s eta 0:00:01
#    --------------------------------- ------ 6.9/8.2 MB 1.4 MB/s eta 0:00:01
#    --------------------------------- ------ 6.9/8.2 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.0/8.2 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.1/8.2 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.1/8.2 MB 1.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.2/8.2 MB 1.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.3/8.2 MB 1.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.3/8.2 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------ --- 7.4/8.2 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------ --- 7.5/8.2 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------ --- 7.5/8.2 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------- -- 7.6/8.2 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------- -- 7.7/8.2 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------- -- 7.8/8.2 MB 1.5 MB/s eta 0:00:01
#    -------------------------------------- - 7.8/8.2 MB 1.5 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.2 MB 1.5 MB/s eta 0:00:01
#    -------------------------------------- - 8.0/8.2 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------  8.0/8.2 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------  8.1/8.2 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------  8.2/8.2 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------  8.2/8.2 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 8.2/8.2 MB 1.5 MB/s eta 0:00:00
# Downloading asgiref-3.8.1-py3-none-any.whl (23 kB)
# Downloading sqlparse-0.5.0-py3-none-any.whl (43 kB)
#    ---------------------------------------- 0.0/44.0 kB ? eta -:--:--
#    ---------------------------------------- 44.0/44.0 kB 1.1 MB/s eta 0:00:00
# Building wheels for collected packages: Image
#   Building wheel for Image (setup.py): started
#   Building wheel for Image (setup.py): finished with status 'done'
#   Created wheel for Image: filename=image-1.5.33-py2.py3-none-any.whl size=19489 sha256=805222b8c37f4d162f848d2035d5040863b466fc22686d96b2c9a9b739b86985
#   Stored in directory: c:\users\merve\appdata\local\pip\cache\wheels\62\40\4f\3c9a8d0f22a1a6f966975a460e5cb509a1e7dc42e2ce5d9a6d
# Successfully built Image
# Installing collected packages: sqlparse, asgiref, django, Image
# Successfully installed Image-1.5.33 asgiref-3.8.1 django-5.0.6 sqlparse-0.5.0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 preprocess_and_create_stylecloud(file_path='genclige_hitabe.txt',
#       2                                  output_name='ay_yildiz.png', icon_name='fas fa-star-and-crescent', lang='turkish')
#
# Cell In[6], line 37, in preprocess_and_create_stylecloud(file_path, output_name, icon_name, lang)
#      34 processed_text = ' '.join(filtered_tokens)
#      36 # StyleCloud oluştur
# ---> 37 stylecloud.gen_stylecloud(text=processed_text,
#      38                           icon_name=icon_name,
#      39                           output_name=output_name)
#      40 # Oluşturulan StyleCloud'u göster
#      41 im = Image.open(output_name)
#
# File ~\anaconda3\Lib\site-packages\stylecloud\stylecloud.py:218, in gen_stylecloud(text, file_path, size, icon_name, palette, colors, background_color, max_font_size, max_words, stopwords, custom_stopwords, add_stopwords, icon_dir, output_name, gradient, font_path, random_state, collocations, invert_mask, pro_icon_path, pro_css_path)
#     215 if file_path:
#     216     text = file_to_text(file_path)
# --> 218 gen_fa_mask(icon_name, size, icon_dir, pro_icon_path, pro_css_path)
#     220 if gradient and colors is None:
#     221     pal_colors, mask_array = gen_gradient_mask(
#     222         size, palette, icon_dir, gradient, invert_mask
#     223     )
#
# File ~\anaconda3\Lib\site-packages\stylecloud\stylecloud.py:76, in gen_fa_mask(icon_name, size, icon_dir, pro_icon_path, pro_css_path)
#      73 if isinstance(size, tuple):
#      74     size = min(size)
# ---> 76 icon.export_icon(
#      77     icon=icon_name_raw[len(icon.common_prefix) :],
#      78     size=size,
#      79     filename="icon.png",
#      80     export_dir=icon_dir,
#      81 )
#
# File ~\anaconda3\Lib\site-packages\icon_font_to_png\icon_font.py:107, in IconFont.export_icon(self, icon, size, color, scale, filename, export_dir)
#     104     scale_factor = float(scale)
#     106 font = ImageFont.truetype(self.ttf_file, int(size * scale_factor))
# --> 107 width, height = draw.textsize(self.css_icons[icon], font=font)
#     109 # If auto-scaling is enabled, we need to make sure the resulting
#     110 # graphic fits inside the boundary. The values are rounded and may be
#     111 # off by a pixel or two, so we may need to do a few iterations.
#     112 # The use of a decrementing multiplication factor protects us from
#     113 # getting into an infinite loop.
#     114 if scale == 'auto':
#
# AttributeError: 'ImageDraw' object has no attribute 'textsize'
# Traceback (most recent call last):
#   File "C:\Users\merve\anaconda3\Lib\site-packages\gradio\queueing.py", line 528, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\merve\anaconda3\Lib\site-packages\gradio\route_utils.py", line 270, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\merve\anaconda3\Lib\site-packages\gradio\blocks.py", line 1908, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\merve\anaconda3\Lib\site-packages\gradio\blocks.py", line 1485, in call_function
#     prediction = await anyio.to_thread.run_sync(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\merve\anaconda3\Lib\site-packages\anyio\to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\merve\anaconda3\Lib\site-packages\anyio\_backends\_asyncio.py", line 2134, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "C:\Users\merve\anaconda3\Lib\site-packages\anyio\_backends\_asyncio.py", line 851, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\merve\anaconda3\Lib\site-packages\gradio\utils.py", line 808, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\merve\AppData\Local\Temp\ipykernel_8152\2664684506.py", line 15, in create_stylecloud
#     stylecloud.gen_stylecloud(text=text,
#   File "C:\Users\merve\anaconda3\Lib\site-packages\stylecloud\stylecloud.py", line 218, in gen_stylecloud
#     gen_fa_mask(icon_name, size, icon_dir, pro_icon_path, pro_css_path)
#   File "C:\Users\merve\anaconda3\Lib\site-packages\stylecloud\stylecloud.py", line 76, in gen_fa_mask
#     icon.export_icon(
#   File "C:\Users\merve\anaconda3\Lib\site-packages\icon_font_to_png\icon_font.py", line 107, in export_icon
#     width, height = draw.textsize(self.css_icons[icon], font=font)
#                     ^^^^^^^^^^^^^
# AttributeError: 'ImageDraw' object has no attribute 'textsize'
# Traceback (most recent call last):
#   File "C:\Users\merve\anaconda3\Lib\site-packages\gradio\queueing.py", line 528, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\merve\anaconda3\Lib\site-packages\gradio\route_utils.py", line 270, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\merve\anaconda3\Lib\site-packages\gradio\blocks.py", line 1908, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\merve\anaconda3\Lib\site-packages\gradio\blocks.py", line 1485, in call_function
#     prediction = await anyio.to_thread.run_sync(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\merve\anaconda3\Lib\site-packages\anyio\to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\merve\anaconda3\Lib\site-packages\anyio\_backends\_asyncio.py", line 2134, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "C:\Users\merve\anaconda3\Lib\site-packages\anyio\_backends\_asyncio.py", line 851, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\merve\anaconda3\Lib\site-packages\gradio\utils.py", line 808, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\merve\AppData\Local\Temp\ipykernel_8152\2664684506.py", line 15, in create_stylecloud
#     stylecloud.gen_stylecloud(text=text,
#   File "C:\Users\merve\anaconda3\Lib\site-packages\stylecloud\stylecloud.py", line 218, in gen_stylecloud
#     gen_fa_mask(icon_name, size, icon_dir, pro_icon_path, pro_css_path)
#   File "C:\Users\merve\anaconda3\Lib\site-packages\stylecloud\stylecloud.py", line 76, in gen_fa_mask
#     icon.export_icon(
#   File "C:\Users\merve\anaconda3\Lib\site-packages\icon_font_to_png\icon_font.py", line 107, in export_icon
#     width, height = draw.textsize(self.css_icons[icon], font=font)
#                     ^^^^^^^^^^^^^
# AttributeError: 'ImageDraw' object has no attribute 'textsize'
# Traceback (most recent call last):
#   File "C:\Users\merve\anaconda3\Lib\site-packages\gradio\queueing.py", line 528, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\merve\anaconda3\Lib\site-packages\gradio\route_utils.py", line 270, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\merve\anaconda3\Lib\site-packages\gradio\blocks.py", line 1908, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\merve\anaconda3\Lib\site-packages\gradio\blocks.py", line 1485, in call_function
#     prediction = await anyio.to_thread.run_sync(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\merve\anaconda3\Lib\site-packages\anyio\to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\merve\anaconda3\Lib\site-packages\anyio\_backends\_asyncio.py", line 2134, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "C:\Users\merve\anaconda3\Lib\site-packages\anyio\_backends\_asyncio.py", line 851, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\merve\anaconda3\Lib\site-packages\gradio\utils.py", line 808, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\merve\AppData\Local\Temp\ipykernel_8152\2664684506.py", line 15, in create_stylecloud
#     stylecloud.gen_stylecloud(text=text,
#   File "C:\Users\merve\anaconda3\Lib\site-packages\stylecloud\stylecloud.py", line 218, in gen_stylecloud
#     gen_fa_mask(icon_name, size, icon_dir, pro_icon_path, pro_css_path)
#   File "C:\Users\merve\anaconda3\Lib\site-packages\stylecloud\stylecloud.py", line 76, in gen_fa_mask
#     icon.export_icon(
#   File "C:\Users\merve\anaconda3\Lib\site-packages\icon_font_to_png\icon_font.py", line 107, in export_icon
#     width, height = draw.textsize(self.css_icons[icon], font=font)
#                     ^^^^^^^^^^^^^
# AttributeError: 'ImageDraw' object has no attribute 'textsize'
# Traceback (most recent call last):
#   File "C:\Users\merve\anaconda3\Lib\site-packages\gradio\queueing.py", line 528, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\merve\anaconda3\Lib\site-packages\gradio\route_utils.py", line 270, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\merve\anaconda3\Lib\site-packages\gradio\blocks.py", line 1908, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\merve\anaconda3\Lib\site-packages\gradio\blocks.py", line 1485, in call_function
#     prediction = await anyio.to_thread.run_sync(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\merve\anaconda3\Lib\site-packages\anyio\to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\merve\anaconda3\Lib\site-packages\anyio\_backends\_asyncio.py", line 2134, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "C:\Users\merve\anaconda3\Lib\site-packages\anyio\_backends\_asyncio.py", line 851, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\merve\anaconda3\Lib\site-packages\gradio\utils.py", line 808, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\merve\AppData\Local\Temp\ipykernel_8152\2664684506.py", line 9, in create_stylecloud
#     text = file.decode("utf-8")
#            ^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'decode'
# Traceback (most recent call last):
#   File "C:\Users\merve\anaconda3\Lib\site-packages\gradio\queueing.py", line 528, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\merve\anaconda3\Lib\site-packages\gradio\route_utils.py", line 270, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\merve\anaconda3\Lib\site-packages\gradio\blocks.py", line 1908, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\merve\anaconda3\Lib\site-packages\gradio\blocks.py", line 1485, in call_function
#     prediction = await anyio.to_thread.run_sync(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\merve\anaconda3\Lib\site-packages\anyio\to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\merve\anaconda3\Lib\site-packages\anyio\_backends\_asyncio.py", line 2134, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "C:\Users\merve\anaconda3\Lib\site-packages\anyio\_backends\_asyncio.py", line 851, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\merve\anaconda3\Lib\site-packages\gradio\utils.py", line 808, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\merve\AppData\Local\Temp\ipykernel_8152\2664684506.py", line 15, in create_stylecloud
#     stylecloud.gen_stylecloud(text=text,
#   File "C:\Users\merve\anaconda3\Lib\site-packages\stylecloud\stylecloud.py", line 218, in gen_stylecloud
#     gen_fa_mask(icon_name, size, icon_dir, pro_icon_path, pro_css_path)
#   File "C:\Users\merve\anaconda3\Lib\site-packages\stylecloud\stylecloud.py", line 76, in gen_fa_mask
#     icon.export_icon(
#   File "C:\Users\merve\anaconda3\Lib\site-packages\icon_font_to_png\icon_font.py", line 107, in export_icon
#     width, height = draw.textsize(self.css_icons[icon], font=font)
#                     ^^^^^^^^^^^^^
# AttributeError: 'ImageDraw' object has no attribute 'textsize'

# %%
import gradio as gr
import stylecloud
from PIL import Image
import os

# Ön işleme ve stylecloud oluşturma fonksiyonu
def create_stylecloud(file, language, icon):
    # Dosyanın içeriğini ikili formatta oku ve decode et
    text = file.decode("utf-8")

    # Geçici bir stylecloud dosyası oluştur
    output_file = "stylecloud.png"
    
    # StyleCloud oluştur
    stylecloud.gen_stylecloud(text=text,
                              icon_name=icon,
                              output_name=output_file)
    
    # Oluşturulan dosyanın yolunu döndür (indirme için)
    return output_file

# Gradio arayüzünü oluştur
with gr.Blocks() as demo:
    gr.Markdown("StyleCloud Oluşturucu")
    with gr.Row():
        file_input = gr.File(label="Metin Dosyası Yükle", type="binary")
        language = gr.Radio(choices=["tr", "en"], label="Dil Seçimi", value="tr")
        icon = gr.Dropdown(choices=["fas fa-car", "fas fa-star-and-crescent", "fas fa-trophy", "fas fa-heart"], label="İkon Seçimi", value="fas fa-star-and-crescent")
    output_file = gr.File(label="Oluşturulan StyleCloud İndir")
    create_button = gr.Button("Oluştur")

    create_button.click(
        create_stylecloud,
        inputs=[file_input, language, icon],
        outputs=output_file
    )

demo.launch(share=True)
# Out:
# Running on local URL:  http://127.0.0.1:7860
#
# Could not create share link. Please check your internet connection or our status page: https://status.gradio.app.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
